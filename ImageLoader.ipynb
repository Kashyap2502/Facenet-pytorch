# %%
import face_recognition
import cv2
import os
import glob
import numpy as np
import time
import pickle
from Facerec import Facerec

# %%
path = "D:\\si\\Faces for Training\\Faces for Training"

# %%
dir_paths=os.listdir(path)

# %%
fr=Facerec()

# %%
for i in dir_paths:
    paths=os.path.join(path,i)
    fr.load_encoding_images(paths)
# Out:
# BLR-1028-00
# BLR-1046-01
# BLR-1195-00
# BLR-1196-00
# BLR-1226-00
# BLR-1227-00
# BLR-1333-00
# BLR-1356-00
# BLR-1361-00
# BLR-1366-00
# BLR-D001-00
# BLR-DDTR02-00
# CPT-1031-00
# CPT-1033-00
# CPT-1038-00
# CPT-1040-00
# CPT-1059-00
# CPT-1060-00
# CPT-1061-00
# CPT-1069-00
# CPT-1082-00
# CPT-1197-00
# CPT-1230-00
# CPT-1232-00
# CPT-1268-00
# CPT-1343-00
# CPT-1357-00
# CPT-23451-01
# CPT-9876-00
# This face is already recorded as CPT-1343-00 no need of CPT-9876-00
# CPT-C031-00
# CPT-C055-00
# CTA-1070-01
# CTA-1077-00
# CTA-1090-00
# CTA-1111-00
# CTA-1117-00
# CTA-1203-00
# CTA-1204-00
# CTA-1205-00
# CTA-1208-00
# CTA-1255-00
# CTA-1260-00
# CTA-1336-02
# CTA-1337-02
# CTA-1338-00
# CTA-1339-00
# CTA-1340-02
# CTA-1354-00
# CTA-1365-00
# CTA-1367-00
# CTA-C048-00
# DBP-1003-00
# DBP-111-00
# DBP-1174-00
# DBP-1180-00
# DBP-C021-00
# DBP-C056-00
# DVH-001-00
# DVH-1009-00
# DVH-1017-00
# DVH-1018-00
# DVH-1019-00
# DVH-1044-00
# DVH-1107-00
# DVH-1111-00
# DVH-1162-00
# DVH-1164-00
# DVH-1171-00
# DVH-1276-00
# DVH-1294-00
# This face is already recorded as DVH-1111-00 no need of DVH-1294-00
# DVH-1334-00
# DVH-1346-00
# DVH-C008-00
# DVH-C021-00
# HAS-00-00
# HAS-1010-03
# HAS-1111-00
# HAS-1122-03
# HAS-1234-00
# HAS-1238-00
# HAS-1239-00
# HAS-1241-05
# HAS-1245-00
# HAS-1257-00
# HAS-1287-03
# HAS-1341-00
# HAS-1352-01
# This face is already recorded as HAS-1111-00 no need of HAS-1352-01
# HAS-1358-01
# HAS-1404-01
# HAS-2222-01
# HAS-3333-06
# This face is already recorded as HAS-1358-01 no need of HAS-3333-06
# HAS-4444-00
# HAS-5555-08
# HAS-C028-04
# HSP-0001-00
# HSP-1161-00
# HSP-123-00
# HSP-1234-00
# HSP-1261-01
# HSP-1263-00
# HSP-1265-00
# HSP-1284-00
# HSP-1285-00
# HSP-1312-00
# HSP-1313-00
# HSP-1337-00
# HSP-1353-00
# HSP-1368-00
# HSP-1372-00
# HSP-1384-00
# HSP-1408-02
# HSP-1424-00
# HSP-3779-00
# HSP-8123-00
# HSP-C051-00
# HUB-1096-00
# HUB-1111-00
# HUB-1329-00
# HUB-1330-00
# HUB-1331-00
# HUB-1332-00
# HUB-1333-00
# HUB-1335-00
# HUB-1369-00
# HUB-1370-00
# HUB-1373-00
# HUB-1392-02
# HUB-5058-00
# HUB-C047-00
# HUB-C050-00
# HUB-C057-00
# HUB-C058-00
# HUB-C059-00
# KLB-1096-00
# KLB-1401-00
# KLB-1405-01
# KLB-1406-00
# KLB-1407-00
# KLB-1411-00
# KLB-C046-01
# KLB-C047-01
# KLB-C054-00
# KLB-SSD032-01
# KLB-SSD033-00
# KLB-SSD034-01
# KLB-SSD105-00
# KLB-SSD107-05
# KLB-SSD115-00
# KLB-SSD117-00
# KLB-SSD118-00
# KLB-SSD119-00
# KLB-SSD120-00
# KLB-SSD125-04
# KLB-SSD127-00
# KLB-SSD128-02
# KLB-SSD129-00
# KLB-SSD130-00
# KNP-1306-00
# KNP-1328-00
# KNP-1331-00
# KNP-1373-00
# KNP-C020-00
# RCH-1096-00
# RCH-1097A-00
# RCH-1099-00
# RCH-1122-00
# RCH-1129-00
# RCH-1130-00
# RCH-1165-00
# RCH-1167-00
# RCH-1210-00
# RCH-1211-00
# RCH-1212-00
# RCH-1216-00
# RCH-1217-00
# RCH-1218-01
# RCH-1233-05
# RCH-1234-00
# RCH-1357-00
# RCH-1372-02
# RCH-1410-00
# RCH-C023-00
# RCH-C045-00
# RCH-C056-00
# RMN-1015-00
# RMN-1335-00
# RMN-1401-00
# RMN-1409-00
# RMN-5057-00
# SJP-00000-00
# SJP-1174-00
# This face is already recorded as DBP-1174-00 no need of SJP-1174-00
# SJP-1225-00
# SJP-1248-01
# SJP-1310-00
# SJP-1311-00
# SJP-1337-00
# SJP-1344-00
# SJP-1359-00
# SJP-1360-02
# SJP-1374-00
# SJP-1400-00
# SJP-C049-00
# SMG-1111-00
# SMG-1234-00
# SMG-12389-00
# SMG-1239-00
# SMG-1256-00
# SMG-1272-00
# SMG-1273-00
# SMG-1286-00
# SMG-1288-00
# SMG-1293-00
# This face is already recorded as SMG-1239-00 no need of SMG-1293-00
# SMG-1347-00
# SMG-TS1111-00
# SMG-TS1112-00
# SMG-TS1113-00
# SMG-TS1114-00
# SMG-TS1115-00
# SMG-TS1116-00
# SMG-TS1117-00
# SMG-TS1118-00
# UTH-1301-00
# This face is already recorded as SJP-1310-00 no need of UTH-1301-00
# UTH-1310-00
# This face is already recorded as SJP-1310-00 no need of UTH-1310-00
# UTH-1399-00
# UTH-5068-00
